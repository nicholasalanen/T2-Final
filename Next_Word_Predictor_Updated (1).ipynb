# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
import torch

# Load model
print("Loading AI model...")
model_name = "distilgpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Loading AI model...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
# Simple example
text = "We are in the class Advanced AI Models and Applications where we"
print(f"\nStarting text: '{text}'")
print("\nGenerating word by word...\n")

# Generate 5 words, one at a time
current_text = text
for step in range(30):
    print(f"--- Step {step + 1} ---")
    print(f"Current: '{current_text}'")

    # Encode current text
    input_ids = tokenizer.encode(current_text, return_tensors="pt")

    # Get predictions
    with torch.no_grad():
        outputs = model(input_ids)
        predictions = outputs.logits

    # Get the predictions for the NEXT token
    next_token_logits = predictions[0, -1, :]
    next_token_probs = torch.softmax(next_token_logits, dim=0)

    # Get top 5 predictions
    top_probs, top_indices = torch.topk(next_token_probs, 3)

    print("Top 5 next word predictions:")
    for i, (prob, idx) in enumerate(zip(top_probs, top_indices)):
        word = tokenizer.decode([idx])
        print(f"  {i+1}. '{word}' ({prob.item()*100:.1f}% confident)")

    # Use the most likely word
    #next_token_id = top_indices[0]
    #next_word = tokenizer.decode([next_token_id])
    #current_text += next_word

    #Choose randomly from top 3 likely words
    choice = torch.randint(0, len(top_indices), (1,)).item()
    next_token_id = top_indices[choice]
    next_word = tokenizer.decode([next_token_id])
    current_text += next_word

    print(f"✓ Chosen: '{next_word}'")
    print(f"New text: '{current_text}'\n")

print(f"\nFinal generated text: '{current_text}'")
# Out:
# Starting text: 'We are in the class Advanced AI Models and Applications where we'
#
# Generating word by word...
#
# --- Step 1 ---
# Current: 'We are in the class Advanced AI Models and Applications where we'
# Top 5 next word predictions:
#   1. ' are' (28.2% confident)
#   2. ' have' (9.4% confident)
#   3. ' will' (6.1% confident)
# ✓ Chosen: ' will'
# New text: 'We are in the class Advanced AI Models and Applications where we will'
#
# --- Step 2 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will'
# Top 5 next word predictions:
#   1. ' be' (19.1% confident)
#   2. ' work' (3.4% confident)
#   3. ' use' (3.3% confident)
# ✓ Chosen: ' use'
# New text: 'We are in the class Advanced AI Models and Applications where we will use'
#
# --- Step 3 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use'
# Top 5 next word predictions:
#   1. ' the' (18.3% confident)
#   2. ' our' (6.5% confident)
#   3. ' a' (3.6% confident)
# ✓ Chosen: ' a'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a'
#
# --- Step 4 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a'
# Top 5 next word predictions:
#   1. ' variety' (6.4% confident)
#   2. ' new' (5.0% confident)
#   3. ' lot' (4.6% confident)
# ✓ Chosen: ' lot'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot'
#
# --- Step 5 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot'
# Top 5 next word predictions:
#   1. ' of' (91.8% confident)
#   2. ' more' (6.5% confident)
#   3. ' to' (0.3% confident)
# ✓ Chosen: ' more'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more'
#
# --- Step 6 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more'
# Top 5 next word predictions:
#   1. ' of' (12.6% confident)
#   2. ' data' (7.7% confident)
#   3. ' advanced' (6.7% confident)
# ✓ Chosen: ' data'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data'
#
# --- Step 7 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data'
# Top 5 next word predictions:
#   1. ' to' (32.8% confident)
#   2. ' and' (12.4% confident)
#   3. ' from' (7.6% confident)
# ✓ Chosen: ' to'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to'
#
# --- Step 8 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to'
# Top 5 next word predictions:
#   1. ' develop' (7.0% confident)
#   2. ' make' (5.2% confident)
#   3. ' build' (4.4% confident)
# ✓ Chosen: ' build'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build'
#
# --- Step 9 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build'
# Top 5 next word predictions:
#   1. ' a' (11.9% confident)
#   2. ' and' (10.5% confident)
#   3. ' our' (6.9% confident)
# ✓ Chosen: ' our'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our'
#
# --- Step 10 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our'
# Top 5 next word predictions:
#   1. ' models' (8.1% confident)
#   2. ' applications' (7.6% confident)
#   3. ' own' (5.7% confident)
# ✓ Chosen: ' applications'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications'
#
# --- Step 11 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications'
# Top 5 next word predictions:
#   1. '.' (38.4% confident)
#   2. ' and' (18.3% confident)
#   3. ',' (10.7% confident)
# ✓ Chosen: '.'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.'
#
# --- Step 12 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.'
# Top 5 next word predictions:
#   1. '
# ' (17.7% confident)
#   2. ' We' (16.9% confident)
#   3. '�' (7.3% confident)
# ✓ Chosen: '�'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.�'
#
# --- Step 13 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.�'
# Top 5 next word predictions:
#   1. '
# ' (46.9% confident)
#   2. '<|endoftext|>' (24.5% confident)
#   3. ' The' (2.0% confident)
# ✓ Chosen: ' The'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The'
#
# --- Step 14 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The'
# Top 5 next word predictions:
#   1. ' data' (3.7% confident)
#   2. ' class' (2.6% confident)
#   3. ' goal' (1.6% confident)
# ✓ Chosen: ' class'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class'
#
# --- Step 15 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class'
# Top 5 next word predictions:
#   1. ' is' (21.5% confident)
#   2. ' will' (10.0% confident)
#   3. ' includes' (5.3% confident)
# ✓ Chosen: ' will'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will'
#
# --- Step 16 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will'
# Top 5 next word predictions:
#   1. ' be' (31.9% confident)
#   2. ' include' (5.8% confident)
#   3. ' focus' (5.4% confident)
# ✓ Chosen: ' focus'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus'
#
# --- Step 17 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus'
# Top 5 next word predictions:
#   1. ' on' (85.3% confident)
#   2. ' primarily' (3.1% confident)
#   3. ' mainly' (1.9% confident)
# ✓ Chosen: ' on'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on'
#
# --- Step 18 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on'
# Top 5 next word predictions:
#   1. ' the' (16.2% confident)
#   2. ' how' (3.1% confident)
#   3. ' AI' (2.0% confident)
# ✓ Chosen: ' the'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the'
#
# --- Step 19 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the'
# Top 5 next word predictions:
#   1. ' application' (1.8% confident)
#   2. ' data' (1.2% confident)
#   3. ' areas' (1.0% confident)
# ✓ Chosen: ' areas'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas'
#
# --- Step 20 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas'
# Top 5 next word predictions:
#   1. ' of' (27.5% confident)
#   2. ' where' (20.6% confident)
#   3. ' that' (17.6% confident)
# ✓ Chosen: ' of'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of'
#
# --- Step 21 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of'
# Top 5 next word predictions:
#   1. ' AI' (10.2% confident)
#   2. ' the' (6.1% confident)
#   3. ' data' (2.4% confident)
# ✓ Chosen: ' the'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the'
#
# --- Step 22 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the'
# Top 5 next word predictions:
#   1. ' AI' (5.5% confident)
#   2. ' application' (3.4% confident)
#   3. ' data' (3.4% confident)
# ✓ Chosen: ' AI'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI'
#
# --- Step 23 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI'
# Top 5 next word predictions:
#   1. ' and' (11.6% confident)
#   2. ' model' (8.6% confident)
#   3. ' that' (6.9% confident)
# ✓ Chosen: ' that'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that'
#
# --- Step 24 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that'
# Top 5 next word predictions:
#   1. ' are' (29.4% confident)
#   2. ' we' (10.0% confident)
#   3. ' need' (6.0% confident)
# ✓ Chosen: ' we'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we'
#
# --- Step 25 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we'
# Top 5 next word predictions:
#   1. ' are' (21.7% confident)
#   2. ' want' (17.4% confident)
#   3. ' will' (9.6% confident)
# ✓ Chosen: ' are'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we are'
#
# --- Step 26 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we are'
# Top 5 next word predictions:
#   1. ' working' (10.7% confident)
#   2. ' interested' (7.9% confident)
#   3. ' developing' (7.6% confident)
# ✓ Chosen: ' developing'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we are developing'
#
# --- Step 27 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we are developing'
# Top 5 next word predictions:
#   1. ' and' (30.3% confident)
#   2. '.' (14.4% confident)
#   3. ',' (10.1% confident)
# ✓ Chosen: '.'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we are developing.'
#
# --- Step 28 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we are developing.'
# Top 5 next word predictions:
#   1. '
# ' (21.7% confident)
#   2. ' We' (17.6% confident)
#   3. ' The' (8.5% confident)
# ✓ Chosen: '
# '
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we are developing.
# '
#
# --- Step 29 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we are developing.
# '
# Top 5 next word predictions:
#   1. '
# ' (97.6% confident)
#   2. 'The' (1.2% confident)
#   3. 'We' (0.1% confident)
# ✓ Chosen: '
# '
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we are developing.
#
# '
#
# --- Step 30 ---
# Current: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we are developing.
#
# '
# Top 5 next word predictions:
#   1. '
# ' (98.9% confident)
#   2. 'The' (0.5% confident)
#   3. 'We' (0.1% confident)
# ✓ Chosen: 'The'
# New text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we are developing.
#
# The'
#
#
# Final generated text: 'We are in the class Advanced AI Models and Applications where we will use a lot more data to build our applications.� The class will focus on the areas of the AI that we are developing.
#
# The'
